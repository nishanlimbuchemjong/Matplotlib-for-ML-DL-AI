# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotting Graph using raw datas

# %%
# raw data of frontend developer
x = [25, 26, 27, 29, 31, 34, 35, 37, 39, 40, 46]
fy = [254, 263, 276, 297, 318, 348, 352, 376, 395, 403, 466]

# %%
# Giving some titiles and labels to make it more informative
plt.plot(x, fy, label='Front-end Developer')

# raw data of backend developer
by = [232, 246, 257, 268, 312, 334, 354, 367, 374, 468, 486]
plt.plot(bx, by, label='Back-end Developer')
plt.title('Median Salary by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary')
plt.legend()
plt.show()

# %% [markdown]
# # Using Format String (color, linestyle)

# %%
# Giving some titiles and labels to make it more informative
plt.plot(x, fy, 'k--', label='Front-end Developer')  # 'k--'-> format string that says black color, dashed line

# raw data of backend developer
by = [232, 246, 257, 268, 312, 334, 354, 367, 374, 468, 486]
plt.plot(bx, by, 'g', label='Back-end Developer')  # 'g' --> green color and other is default
plt.title('Median Salary by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary')
plt.legend()
plt.show()

# %% [markdown]
# # Using Format String (color, linestyle, markers)

# %%
# Giving some titiles and labels to make it more informative
plt.plot(x, fy, color='k', label='Front-end Developer') 

# raw data of backend developer
by = [232, 246, 257, 268, 312, 334, 354, 367, 374, 468, 486]
plt.plot(x, by, color='g', label='Back-end Developer')  
plt.title('Median Salary by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary')
plt.legend()
plt.show()

# %% [markdown]
# # Plotting BarGraph

# %%
import numpy as np

# %%
# Giving some titiles and labels to make it more informative
plt.bar(x, fy, color='b', label='Front-end Developer') 

# raw data of backend developer
by = [232, 246, 257, 268, 312, 334, 354, 367, 374, 468, 486]
plt.bar(x, by, color='g',label='Back-end Developer')  
plt.title('Median Salary by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary')
plt.legend()
plt.show()

# %%
x_indixes = np.arange(len(x))
width = 0.25

plt.bar(x_indixes - width, fy, width=width, color='y', label='Front-end Developer') 

# raw data of backend developer
by = [232, 246, 257, 268, 312, 334, 354, 367, 374, 468, 486]
plt.bar(x_indixes, by, width=width, color='g',label='Back-end Developer')  
plt.xticks(ticks=x_indixes, labels=x)  # used to correct the indexes of age
plt.title('Median Salary by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary')
plt.legend()
plt.show()
